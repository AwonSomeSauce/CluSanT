# %%
import re
import json
import pandas as pd
import numpy as np
from openai import OpenAI
from tqdm import tqdm

# %%
df = pd.read_csv("../anonymized_texts.csv")
custext_df = pd.read_csv("../anonymized_texts_custext.csv")

# %%
# Filter the dataframe
df = df[(df['loc_and_org'] == True) & (df['dp_type'] == 'metric')]
custext_df = custext_df[(custext_df['loc_and_org'] == True) & (custext_df['dp_type'] == 'metric')]

# %%
# Creating the new 'Custome_ID' column
# custext_df['Custome_ID'] = ['request-{}'.format(i) for i in range(1, len(custext_df) + 1)]
# custext_df = custext_df.rename(columns={'Custome_ID': 'Custom_ID'})
# custext_df.to_csv("../anonymized_texts_custext.csv", index=False)

# %%
print(df.shape)
print(custext_df.shape)
# Out:
# (25167, 11)
# (4445, 11)

# %%
custext_df.head()
# Out:
#    loc_and_org  epsilon  num_cluster   K dp_type  \
# 0         True      0.1            1 NaN  metric
# 1         True      0.1            1 NaN  metric
# 2         True      0.1            1 NaN  metric
# 3         True      0.1            1 NaN  metric
# 4         True      0.1            1 NaN  metric
#
#                                      anonymized_text  Grammar  Common Sense  \
# 0  PROCEDURE\n\nThe case originated in an applica...      NaN           NaN
# 1  PROCEDURE\n\nThe case originated in an applica...      NaN           NaN
# 2  PROCEDURE\n\nThe case originated in an applica...      NaN           NaN
# 3  PROCEDURE\n\nThe case originated in an applica...      NaN           NaN
# 4  PROCEDURE\n\nThe case originated in an applica...      NaN           NaN
#
#    Coherence  Cohesiveness  Custom_ID
# 0        NaN           NaN  request-1
# 1        NaN           NaN  request-2
# 2        NaN           NaN  request-3
# 3        NaN           NaN  request-4
# 4        NaN           NaN  request-5

# %%
def get_number_of_unique_combinations(any_df):
    unique_combinations = any_df.drop_duplicates(subset=['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type'])

    # Get the number of unique combinations
    return unique_combinations.shape[0]

# Function to filter and sample 45 rows from each group
def filter_and_sample_rows(group):
    # Filter rows where the length of "anonymized_text" is less than 5000 characters
    filtered_group = group[group['anonymized_text'].str.len() < 5000]
    # Sample 45 rows from the filtered group
    return filtered_group.sample(n=45, replace=False)

# %%
# Group by the specified columns and apply the filter and sampling function
sampled_df = df.groupby(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type']).apply(filter_and_sample_rows).reset_index(drop=True)

# Assert check to ensure the number of unique combinations is the same
assert get_number_of_unique_combinations(df) == get_number_of_unique_combinations(sampled_df), "The number of unique combinations does not match!"
# Out:
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_4456/2746746421.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type']).apply(filter_and_sample_rows).reset_index(drop=True)

# %%
# Group by the specified columns and apply the filter and sampling function
sampled_df_custext = custext_df.groupby(['epsilon', 'num_cluster']).apply(filter_and_sample_rows).reset_index(drop=True)

# Assert check to ensure the number of unique combinations is the same
assert get_number_of_unique_combinations(custext_df) == get_number_of_unique_combinations(sampled_df_custext), "The number of unique combinations does not match!"
# Out:
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_4456/1999967498.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df_custext = custext_df.groupby(['epsilon', 'num_cluster']).apply(filter_and_sample_rows).reset_index(drop=True)

# %%
print(custext_df.shape[0])
print(sampled_df_custext.shape[0])
# Out:
# 4445
# 1575

# %%
filtered_df = sampled_df_custext[sampled_df_custext['Grammar'].isnull() & sampled_df_custext['Common Sense'].isnull() & sampled_df_custext['Coherence'].isnull() & sampled_df_custext['Cohesiveness'].isnull()]
# random_df = filtered_df.sample(n=1000, random_state=42)
random_df = filtered_df.copy()
print(random_df.shape[0])
# Out:
# 1575

# %%
client = OpenAI(organization="org-5FDaIDe2hzj7FGqPPiL6V4Jk")

# %%
system_message = (
    "Could you please evaluate the following passage for its grammar, common sense, "
    "coherence, and cohesiveness? Score it on a scale from 1 to 5, where 1 is the lowest "
    "(poor quality) and 5 is the highest (excellent quality). "
    "You should score based on these criteria:\n"
    "grammar: Are the sentences structured correctly?\n"
    "common sense: Does the content make logical sense in the real world?\n"
    "coherence: Do the ideas flow logically from one sentence to another?\n"
    "cohesiveness: Do all parts of the text come together in a unified whole?\n"
    "Please ONLY respond in JSON format with the only four keys 'grammar', 'common sense', "
    "'coherence', and 'cohesiveness', each with a score attached to them."
)

# %%
# Prepare to write to a JSONL file
with open('requests_custext.jsonl', 'w') as file:
    for index, row in tqdm(random_df.iterrows(), total=random_df.shape[0]):
        # Get custom_id
        custom_id = row['Custom_ID']

        # Clean and process comment
        comment = str(row['anonymized_text']).strip()
        comment = re.sub(r'\s+', ' ', comment)

        user_message = f"passage: {comment}"

        # Construct JSON object
        json_object = {
            "custom_id": custom_id,
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": {
                "model": "gpt-4o",
                "messages": [
                    {"role": "system", "content": system_message},
                    {"role": "user", "content": user_message}
                ],
                "max_tokens": 500
            }
        }

        # Write JSON object to file
        json.dump(json_object, file)
        file.write('\n')
# Out:
# 100%|██████████| 1575/1575 [00:00<00:00, 6271.38it/s]

# %%
batch_input_file = client.files.create(
  file=open("requests_custext.jsonl", "rb"),
  purpose="batch"
)

batch_input_file_id = batch_input_file.id

response = client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={
      "description": "nightly CluSanT evaluating job"
    }
)

print(response)
# Out:
# Batch(id='batch_wXpX3fHS3L6TK6gwsDr8uCC5', completion_window='24h', created_at=1717986586, endpoint='/v1/chat/completions', input_file_id='file-eOCJgJuOf5ecWpcF65gPvXCJ', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1718072986, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'nightly CluSanT evaluating job'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %%
print(client.batches.retrieve("batch_wXpX3fHS3L6TK6gwsDr8uCC5"))
# Out:
# Batch(id='batch_wXpX3fHS3L6TK6gwsDr8uCC5', completion_window='24h', created_at=1717986586, endpoint='/v1/chat/completions', input_file_id='file-eOCJgJuOf5ecWpcF65gPvXCJ', object='batch', status='in_progress', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1718072986, failed_at=None, finalizing_at=None, in_progress_at=1718035500, metadata={'description': 'nightly CluSanT evaluating job'}, output_file_id=None, request_counts=BatchRequestCounts(completed=1573, failed=0, total=1575))

# %%
content = client.files.content("file-S5K0gUZ692qKg8co22Nv8c6F")
with open("requests_output_custext.jsonl", "ab") as file:
    file.write(content.content)

# %%
custext_df = pd.read_csv("../anonymized_texts_custext.csv")

# Read the JSONL file
data = []
with open('requests_output_custext.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Function to clean and parse the content from the markdown code block
def parse_content(content):
    try:
        # Strip the triple backticks and any extra whitespace or newlines
        clean_content = content.replace("```json\n", "").replace("\n```", "").strip()
        parsed_content = json.loads(clean_content)
        # Convert the keys of the dictionary to lowercase
        return {k.lower(): v for k, v in parsed_content.items()}
    except json.JSONDecodeError:
        # Return None or an empty dictionary if JSON decoding fails
        return {}

# Iterate through the loaded JSON data and update the DataFrame
for item in data:
    custom_id = item['custom_id']
    content = parse_content(item['response']['body']['choices'][0]['message']['content'])
    if custom_id in custext_df['Custom_ID'].values:
        # Convert the content dictionary back to a JSON string to store in the DataFrame
        custext_df.loc[custext_df['Custom_ID'] == custom_id, 'Grammar'] = json.dumps(content['grammar']) if 'grammar' in content else None
        custext_df.loc[custext_df['Custom_ID'] == custom_id, 'Common Sense'] = json.dumps(content['common sense']) if 'common sense' in content else None
        custext_df.loc[custext_df['Custom_ID'] == custom_id, 'Coherence'] = json.dumps(content['coherence']) if 'coherence' in content else None
        custext_df.loc[custext_df['Custom_ID'] == custom_id, 'Cohesiveness'] = json.dumps(content['cohesiveness']) if 'cohesiveness' in content else None
    else:
        print(f"Custom_ID {custom_id} not found in DataFrame.")

print(custext_df['Grammar'].notna().sum())
# Out:
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_2042/1890971241.py:27: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Custom_ID'] == custom_id, 'Grammar'] = json.dumps(content['grammar']) if 'grammar' in content else None
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_2042/1890971241.py:28: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Custom_ID'] == custom_id, 'Common Sense'] = json.dumps(content['common sense']) if 'common sense' in content else None
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_2042/1890971241.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Custom_ID'] == custom_id, 'Coherence'] = json.dumps(content['coherence']) if 'coherence' in content else None
# /var/folders/r5/4hm22tj92532tlxq6h4frrp40000gn/T/ipykernel_2042/1890971241.py:30: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Custom_ID'] == custom_id, 'Cohesiveness'] = json.dumps(content['cohesiveness']) if 'cohesiveness' in content else None
# 9954

# %%
custext_df.to_csv("../anonymized_texts.csv", index=False)

# %% [markdown]
# ## Generate Results

# %%
df = pd.read_csv("../anonymized_texts.csv")
filtered_df = df[(df['loc_and_org'] == True) & (df['dp_type'] == 'metric')]
filtered_df = filtered_df[filtered_df['Grammar'].notna() | filtered_df['Common Sense'].notna() | filtered_df['Coherence'].notna() | filtered_df['Cohesiveness'].notna()]

# %%
filtered_df.columns
# Out:
# Index(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type',
#        'anonymized_text', 'Custom_ID', 'Grammar', 'Common Sense', 'Coherence',
#        'Cohesiveness'],
#       dtype='object')

# %%
filtered_df.shape[0]
# Out:
# 9237

# %%
# Group by the specified columns and count the number of records in each group
grouped_df = filtered_df.groupby(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type']).size().reset_index(name='counts')

# Iterate over the grouped dataframe and print each combination and the number of records
for index, row in grouped_df.iterrows():
    combination = (row['loc_and_org'], row['epsilon'], row['num_cluster'], row['K'], row['dp_type'])
    count = row['counts']
    print(f"Combination: {combination}, Number of records: {count}")

# Check if all combinations have the same number of records
if grouped_df['counts'].nunique() == 1:
    print("All combinations have the same number of records.")
else:
    print("Different combinations have different numbers of records.")
# Out:
# Combination: (True, 0.1, 1, 1, 'metric'), Number of records: 48
# Combination: (True, 0.1, 1, 8, 'metric'), Number of records: 45
# Combination: (True, 0.1, 1, 16, 'metric'), Number of records: 43
# Combination: (True, 0.1, 1, 32, 'metric'), Number of records: 43
# Combination: (True, 0.1, 1, 64, 'metric'), Number of records: 44
# Combination: (True, 0.1, 40, 1, 'metric'), Number of records: 45
# Combination: (True, 0.1, 40, 8, 'metric'), Number of records: 47
# Combination: (True, 0.1, 40, 16, 'metric'), Number of records: 48
# Combination: (True, 0.1, 40, 32, 'metric'), Number of records: 46
# Combination: (True, 0.1, 40, 64, 'metric'), Number of records: 45
# Combination: (True, 0.1, 40, 128, 'metric'), Number of records: 48
# Combination: (True, 0.1, 180, 1, 'metric'), Number of records: 48
# Combination: (True, 0.1, 180, 8, 'metric'), Number of records: 46
# Combination: (True, 0.1, 180, 16, 'metric'), Number of records: 50
# Combination: (True, 0.1, 180, 32, 'metric'), Number of records: 45
# Combination: (True, 0.1, 180, 64, 'metric'), Number of records: 47
# Combination: (True, 0.1, 180, 128, 'metric'), Number of records: 48
# Combination: (True, 0.1, 360, 1, 'metric'), Number of records: 47
# Combination: (True, 0.1, 360, 8, 'metric'), Number of records: 46
# Combination: (True, 0.1, 360, 16, 'metric'), Number of records: 47
# Combination: (True, 0.1, 360, 32, 'metric'), Number of records: 47
# Combination: (True, 0.1, 360, 64, 'metric'), Number of records: 44
# Combination: (True, 0.1, 360, 128, 'metric'), Number of records: 46
# Combination: (True, 0.1, 720, 1, 'metric'), Number of records: 51
# Combination: (True, 0.1, 720, 8, 'metric'), Number of records: 45
# Combination: (True, 0.1, 720, 16, 'metric'), Number of records: 50
# Combination: (True, 0.1, 720, 32, 'metric'), Number of records: 47
# Combination: (True, 0.1, 720, 64, 'metric'), Number of records: 43
# Combination: (True, 0.1, 720, 128, 'metric'), Number of records: 48
# Combination: (True, 0.5, 1, 1, 'metric'), Number of records: 46
# Combination: (True, 0.5, 1, 8, 'metric'), Number of records: 46
# Combination: (True, 0.5, 1, 16, 'metric'), Number of records: 50
# Combination: (True, 0.5, 1, 32, 'metric'), Number of records: 47
# Combination: (True, 0.5, 1, 64, 'metric'), Number of records: 46
# Combination: (True, 0.5, 40, 1, 'metric'), Number of records: 47
# Combination: (True, 0.5, 40, 8, 'metric'), Number of records: 44
# Combination: (True, 0.5, 40, 16, 'metric'), Number of records: 49
# Combination: (True, 0.5, 40, 32, 'metric'), Number of records: 45
# Combination: (True, 0.5, 40, 64, 'metric'), Number of records: 48
# Combination: (True, 0.5, 40, 128, 'metric'), Number of records: 45
# Combination: (True, 0.5, 180, 1, 'metric'), Number of records: 45
# Combination: (True, 0.5, 180, 8, 'metric'), Number of records: 47
# Combination: (True, 0.5, 180, 16, 'metric'), Number of records: 45
# Combination: (True, 0.5, 180, 32, 'metric'), Number of records: 46
# Combination: (True, 0.5, 180, 64, 'metric'), Number of records: 48
# Combination: (True, 0.5, 180, 128, 'metric'), Number of records: 48
# Combination: (True, 0.5, 360, 1, 'metric'), Number of records: 48
# Combination: (True, 0.5, 360, 8, 'metric'), Number of records: 47
# Combination: (True, 0.5, 360, 16, 'metric'), Number of records: 49
# Combination: (True, 0.5, 360, 32, 'metric'), Number of records: 48
# Combination: (True, 0.5, 360, 64, 'metric'), Number of records: 46
# Combination: (True, 0.5, 360, 128, 'metric'), Number of records: 47
# Combination: (True, 0.5, 720, 1, 'metric'), Number of records: 45
# Combination: (True, 0.5, 720, 8, 'metric'), Number of records: 47
# Combination: (True, 0.5, 720, 16, 'metric'), Number of records: 46
# Combination: (True, 0.5, 720, 32, 'metric'), Number of records: 46
# Combination: (True, 0.5, 720, 64, 'metric'), Number of records: 46
# Combination: (True, 0.5, 720, 128, 'metric'), Number of records: 49
# Combination: (True, 1.0, 1, 1, 'metric'), Number of records: 49
# Combination: (True, 1.0, 1, 8, 'metric'), Number of records: 46
# Combination: (True, 1.0, 1, 16, 'metric'), Number of records: 46
# Combination: (True, 1.0, 1, 32, 'metric'), Number of records: 48
# Combination: (True, 1.0, 40, 1, 'metric'), Number of records: 47
# Combination: (True, 1.0, 40, 8, 'metric'), Number of records: 48
# Combination: (True, 1.0, 40, 16, 'metric'), Number of records: 46
# Combination: (True, 1.0, 40, 32, 'metric'), Number of records: 45
# Combination: (True, 1.0, 40, 64, 'metric'), Number of records: 48
# Combination: (True, 1.0, 40, 128, 'metric'), Number of records: 48
# Combination: (True, 1.0, 180, 1, 'metric'), Number of records: 46
# Combination: (True, 1.0, 180, 8, 'metric'), Number of records: 43
# Combination: (True, 1.0, 180, 16, 'metric'), Number of records: 44
# Combination: (True, 1.0, 180, 32, 'metric'), Number of records: 45
# Combination: (True, 1.0, 180, 64, 'metric'), Number of records: 45
# Combination: (True, 1.0, 180, 128, 'metric'), Number of records: 44
# Combination: (True, 1.0, 360, 1, 'metric'), Number of records: 48
# Combination: (True, 1.0, 360, 8, 'metric'), Number of records: 47
# Combination: (True, 1.0, 360, 16, 'metric'), Number of records: 44
# Combination: (True, 1.0, 360, 32, 'metric'), Number of records: 46
# Combination: (True, 1.0, 360, 64, 'metric'), Number of records: 50
# Combination: (True, 1.0, 360, 128, 'metric'), Number of records: 47
# Combination: (True, 1.0, 720, 1, 'metric'), Number of records: 46
# Combination: (True, 1.0, 720, 8, 'metric'), Number of records: 47
# Combination: (True, 1.0, 720, 16, 'metric'), Number of records: 47
# Combination: (True, 1.0, 720, 32, 'metric'), Number of records: 47
# Combination: (True, 1.0, 720, 64, 'metric'), Number of records: 48
# Combination: (True, 1.0, 720, 128, 'metric'), Number of records: 46
# Combination: (True, 2.0, 1, 1, 'metric'), Number of records: 44
# Combination: (True, 2.0, 1, 8, 'metric'), Number of records: 47
# Combination: (True, 2.0, 1, 16, 'metric'), Number of records: 41
# Combination: (True, 2.0, 1, 32, 'metric'), Number of records: 47
# Combination: (True, 2.0, 40, 1, 'metric'), Number of records: 48
# Combination: (True, 2.0, 40, 8, 'metric'), Number of records: 50
# Combination: (True, 2.0, 40, 16, 'metric'), Number of records: 47
# Combination: (True, 2.0, 40, 32, 'metric'), Number of records: 47
# Combination: (True, 2.0, 40, 64, 'metric'), Number of records: 48
# Combination: (True, 2.0, 40, 128, 'metric'), Number of records: 48
# Combination: (True, 2.0, 180, 1, 'metric'), Number of records: 50
# Combination: (True, 2.0, 180, 8, 'metric'), Number of records: 45
# Combination: (True, 2.0, 180, 16, 'metric'), Number of records: 45
# Combination: (True, 2.0, 180, 32, 'metric'), Number of records: 47
# Combination: (True, 2.0, 180, 64, 'metric'), Number of records: 45
# Combination: (True, 2.0, 180, 128, 'metric'), Number of records: 48
# Combination: (True, 2.0, 360, 1, 'metric'), Number of records: 48
# Combination: (True, 2.0, 360, 8, 'metric'), Number of records: 47
# Combination: (True, 2.0, 360, 16, 'metric'), Number of records: 49
# Combination: (True, 2.0, 360, 32, 'metric'), Number of records: 48
# Combination: (True, 2.0, 360, 64, 'metric'), Number of records: 47
# Combination: (True, 2.0, 360, 128, 'metric'), Number of records: 47
# Combination: (True, 2.0, 720, 1, 'metric'), Number of records: 44
# Combination: (True, 2.0, 720, 8, 'metric'), Number of records: 47
# Combination: (True, 2.0, 720, 16, 'metric'), Number of records: 46
# Combination: (True, 2.0, 720, 32, 'metric'), Number of records: 48
# Combination: (True, 2.0, 720, 64, 'metric'), Number of records: 47
# Combination: (True, 2.0, 720, 128, 'metric'), Number of records: 49
# Combination: (True, 4.0, 1, 1, 'metric'), Number of records: 48
# Combination: (True, 4.0, 1, 8, 'metric'), Number of records: 49
# Combination: (True, 4.0, 1, 16, 'metric'), Number of records: 45
# Combination: (True, 4.0, 1, 32, 'metric'), Number of records: 46
# Combination: (True, 4.0, 40, 1, 'metric'), Number of records: 49
# Combination: (True, 4.0, 40, 8, 'metric'), Number of records: 45
# Combination: (True, 4.0, 40, 16, 'metric'), Number of records: 45
# Combination: (True, 4.0, 40, 32, 'metric'), Number of records: 43
# Combination: (True, 4.0, 40, 64, 'metric'), Number of records: 46
# Combination: (True, 4.0, 40, 128, 'metric'), Number of records: 45
# Combination: (True, 4.0, 180, 1, 'metric'), Number of records: 46
# Combination: (True, 4.0, 180, 8, 'metric'), Number of records: 46
# Combination: (True, 4.0, 180, 16, 'metric'), Number of records: 49
# Combination: (True, 4.0, 180, 32, 'metric'), Number of records: 46
# Combination: (True, 4.0, 180, 64, 'metric'), Number of records: 47
# Combination: (True, 4.0, 180, 128, 'metric'), Number of records: 47
# Combination: (True, 4.0, 360, 1, 'metric'), Number of records: 44
# Combination: (True, 4.0, 360, 8, 'metric'), Number of records: 49
# Combination: (True, 4.0, 360, 16, 'metric'), Number of records: 46
# Combination: (True, 4.0, 360, 32, 'metric'), Number of records: 46
# Combination: (True, 4.0, 360, 64, 'metric'), Number of records: 45
# Combination: (True, 4.0, 360, 128, 'metric'), Number of records: 46
# Combination: (True, 4.0, 720, 1, 'metric'), Number of records: 46
# Combination: (True, 4.0, 720, 8, 'metric'), Number of records: 44
# Combination: (True, 4.0, 720, 16, 'metric'), Number of records: 47
# Combination: (True, 4.0, 720, 32, 'metric'), Number of records: 43
# Combination: (True, 4.0, 720, 64, 'metric'), Number of records: 47
# Combination: (True, 4.0, 720, 128, 'metric'), Number of records: 46
# Combination: (True, 8.0, 1, 1, 'metric'), Number of records: 47
# Combination: (True, 8.0, 1, 8, 'metric'), Number of records: 49
# Combination: (True, 8.0, 1, 16, 'metric'), Number of records: 46
# Combination: (True, 8.0, 1, 32, 'metric'), Number of records: 46
# Combination: (True, 8.0, 40, 1, 'metric'), Number of records: 45
# Combination: (True, 8.0, 40, 8, 'metric'), Number of records: 44
# Combination: (True, 8.0, 40, 16, 'metric'), Number of records: 46
# Combination: (True, 8.0, 40, 32, 'metric'), Number of records: 45
# Combination: (True, 8.0, 40, 64, 'metric'), Number of records: 47
# Combination: (True, 8.0, 40, 128, 'metric'), Number of records: 47
# Combination: (True, 8.0, 180, 1, 'metric'), Number of records: 45
# Combination: (True, 8.0, 180, 8, 'metric'), Number of records: 47
# Combination: (True, 8.0, 180, 16, 'metric'), Number of records: 48
# Combination: (True, 8.0, 180, 32, 'metric'), Number of records: 47
# Combination: (True, 8.0, 180, 64, 'metric'), Number of records: 50
# Combination: (True, 8.0, 180, 128, 'metric'), Number of records: 49
# Combination: (True, 8.0, 360, 1, 'metric'), Number of records: 46
# Combination: (True, 8.0, 360, 8, 'metric'), Number of records: 48
# Combination: (True, 8.0, 360, 16, 'metric'), Number of records: 49
# Combination: (True, 8.0, 360, 32, 'metric'), Number of records: 46
# Combination: (True, 8.0, 360, 64, 'metric'), Number of records: 47
# Combination: (True, 8.0, 360, 128, 'metric'), Number of records: 49
# Combination: (True, 8.0, 720, 1, 'metric'), Number of records: 43
# Combination: (True, 8.0, 720, 8, 'metric'), Number of records: 48
# Combination: (True, 8.0, 720, 16, 'metric'), Number of records: 47
# Combination: (True, 8.0, 720, 32, 'metric'), Number of records: 47
# Combination: (True, 8.0, 720, 64, 'metric'), Number of records: 46
# Combination: (True, 8.0, 720, 128, 'metric'), Number of records: 47
# Combination: (True, 16.0, 1, 1, 'metric'), Number of records: 45
# Combination: (True, 16.0, 1, 8, 'metric'), Number of records: 43
# Combination: (True, 16.0, 1, 16, 'metric'), Number of records: 47
# Combination: (True, 16.0, 1, 32, 'metric'), Number of records: 48
# Combination: (True, 16.0, 40, 1, 'metric'), Number of records: 43
# Combination: (True, 16.0, 40, 8, 'metric'), Number of records: 50
# Combination: (True, 16.0, 40, 16, 'metric'), Number of records: 48
# Combination: (True, 16.0, 40, 32, 'metric'), Number of records: 50
# Combination: (True, 16.0, 40, 64, 'metric'), Number of records: 50
# Combination: (True, 16.0, 40, 128, 'metric'), Number of records: 47
# Combination: (True, 16.0, 180, 1, 'metric'), Number of records: 47
# Combination: (True, 16.0, 180, 8, 'metric'), Number of records: 47
# Combination: (True, 16.0, 180, 16, 'metric'), Number of records: 46
# Combination: (True, 16.0, 180, 32, 'metric'), Number of records: 47
# Combination: (True, 16.0, 180, 64, 'metric'), Number of records: 49
# Combination: (True, 16.0, 180, 128, 'metric'), Number of records: 47
# Combination: (True, 16.0, 360, 1, 'metric'), Number of records: 45
# Combination: (True, 16.0, 360, 8, 'metric'), Number of records: 48
# Combination: (True, 16.0, 360, 16, 'metric'), Number of records: 48
# Combination: (True, 16.0, 360, 32, 'metric'), Number of records: 45
# Combination: (True, 16.0, 360, 64, 'metric'), Number of records: 45
# Combination: (True, 16.0, 360, 128, 'metric'), Number of records: 48
# Combination: (True, 16.0, 720, 1, 'metric'), Number of records: 46
# Combination: (True, 16.0, 720, 8, 'metric'), Number of records: 47
# Combination: (True, 16.0, 720, 16, 'metric'), Number of records: 48
# Combination: (True, 16.0, 720, 32, 'metric'), Number of records: 47
# Combination: (True, 16.0, 720, 64, 'metric'), Number of records: 49
# Combination: (True, 16.0, 720, 128, 'metric'), Number of records: 47
# Different combinations have different numbers of records.

# %%
# Replace the None values with NaN for proper handling
filtered_df[['Grammar', 'Common Sense', 'Coherence', 'Cohesiveness']] = filtered_df[['Grammar', 'Common Sense', 'Coherence', 'Cohesiveness']].apply(pd.to_numeric, errors='coerce')

# Group by the specified columns and calculate the average for the specified columns
grouped_averages = filtered_df.groupby(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type']).agg({
    'Grammar': 'mean',
    'Common Sense': 'mean',
    'Coherence': 'mean',
    'Cohesiveness': 'mean'
}).reset_index()

# Iterate over the grouped dataframe and print each combination and the average values
for index, row in grouped_averages.iterrows():
    combination = (row['loc_and_org'], row['epsilon'], row['num_cluster'], row['K'], row['dp_type'])
    grammar_avg = row['Grammar']
    common_sense_avg = row['Common Sense']
    coherence_avg = row['Coherence']
    cohesiveness_avg = row['Cohesiveness']
    print(f"Combination: {combination}, Averages -> Grammar: {grammar_avg}, Common Sense: {common_sense_avg}, Coherence: {coherence_avg}, Cohesiveness: {cohesiveness_avg}")
# Out:
# Combination: (True, 0.1, 1, 1, 'metric'), Averages -> Grammar: 3.1875, Common Sense: 2.382978723404255, Coherence: 2.5625, Cohesiveness: 2.5
# Combination: (True, 0.1, 1, 8, 'metric'), Averages -> Grammar: 3.3555555555555556, Common Sense: 2.4545454545454546, Coherence: 2.6444444444444444, Cohesiveness: 2.5555555555555554
# Combination: (True, 0.1, 1, 16, 'metric'), Averages -> Grammar: 3.302325581395349, Common Sense: 2.4651162790697674, Coherence: 2.5348837209302326, Cohesiveness: 2.4186046511627906
# Combination: (True, 0.1, 1, 32, 'metric'), Averages -> Grammar: 3.3255813953488373, Common Sense: 2.441860465116279, Coherence: 2.6744186046511627, Cohesiveness: 2.5813953488372094
# Combination: (True, 0.1, 1, 64, 'metric'), Averages -> Grammar: 3.227272727272727, Common Sense: 2.4545454545454546, Coherence: 2.5454545454545454, Cohesiveness: 2.5681818181818183
# Combination: (True, 0.1, 40, 1, 'metric'), Averages -> Grammar: 3.4, Common Sense: 2.5348837209302326, Coherence: 2.6222222222222222, Cohesiveness: 2.7333333333333334
# Combination: (True, 0.1, 40, 8, 'metric'), Averages -> Grammar: 3.234042553191489, Common Sense: 2.5851063829787235, Coherence: 2.574468085106383, Cohesiveness: 2.574468085106383
# Combination: (True, 0.1, 40, 16, 'metric'), Averages -> Grammar: 3.125, Common Sense: 2.25531914893617, Coherence: 2.5, Cohesiveness: 2.4375
# Combination: (True, 0.1, 40, 32, 'metric'), Averages -> Grammar: 3.1739130434782608, Common Sense: 2.4565217391304346, Coherence: 2.5869565217391304, Cohesiveness: 2.4347826086956523
# Combination: (True, 0.1, 40, 64, 'metric'), Averages -> Grammar: 3.4, Common Sense: 2.522727272727273, Coherence: 2.8444444444444446, Cohesiveness: 2.8
# Combination: (True, 0.1, 40, 128, 'metric'), Averages -> Grammar: 3.4166666666666665, Common Sense: 2.5625, Coherence: 2.8958333333333335, Cohesiveness: 2.7708333333333335
# Combination: (True, 0.1, 180, 1, 'metric'), Averages -> Grammar: 3.3333333333333335, Common Sense: 2.4791666666666665, Coherence: 2.625, Cohesiveness: 2.6041666666666665
# Combination: (True, 0.1, 180, 8, 'metric'), Averages -> Grammar: 3.1739130434782608, Common Sense: 2.369565217391304, Coherence: 2.5, Cohesiveness: 2.4782608695652173
# Combination: (True, 0.1, 180, 16, 'metric'), Averages -> Grammar: 3.24, Common Sense: 2.4583333333333335, Coherence: 2.52, Cohesiveness: 2.46
# Combination: (True, 0.1, 180, 32, 'metric'), Averages -> Grammar: 3.1555555555555554, Common Sense: 2.4651162790697674, Coherence: 2.533333333333333, Cohesiveness: 2.466666666666667
# Combination: (True, 0.1, 180, 64, 'metric'), Averages -> Grammar: 3.297872340425532, Common Sense: 2.4680851063829787, Coherence: 2.6595744680851063, Cohesiveness: 2.5531914893617023
# Combination: (True, 0.1, 180, 128, 'metric'), Averages -> Grammar: 3.4375, Common Sense: 2.688888888888889, Coherence: 2.8333333333333335, Cohesiveness: 2.75
# Combination: (True, 0.1, 360, 1, 'metric'), Averages -> Grammar: 3.234042553191489, Common Sense: 2.5652173913043477, Coherence: 2.617021276595745, Cohesiveness: 2.6382978723404253
# Combination: (True, 0.1, 360, 8, 'metric'), Averages -> Grammar: 3.3043478260869565, Common Sense: 2.5555555555555554, Coherence: 2.608695652173913, Cohesiveness: 2.5434782608695654
# Combination: (True, 0.1, 360, 16, 'metric'), Averages -> Grammar: 3.3191489361702127, Common Sense: 2.6444444444444444, Coherence: 2.617021276595745, Cohesiveness: 2.595744680851064
# Combination: (True, 0.1, 360, 32, 'metric'), Averages -> Grammar: 3.25531914893617, Common Sense: 2.4545454545454546, Coherence: 2.574468085106383, Cohesiveness: 2.5319148936170213
# Combination: (True, 0.1, 360, 64, 'metric'), Averages -> Grammar: 3.272727272727273, Common Sense: 2.3863636363636362, Coherence: 2.6136363636363638, Cohesiveness: 2.5681818181818183
# Combination: (True, 0.1, 360, 128, 'metric'), Averages -> Grammar: 3.3043478260869565, Common Sense: 2.5652173913043477, Coherence: 2.6956521739130435, Cohesiveness: 2.6739130434782608
# Combination: (True, 0.1, 720, 1, 'metric'), Averages -> Grammar: 3.2549019607843137, Common Sense: 2.42, Coherence: 2.5098039215686274, Cohesiveness: 2.5294117647058822
# Combination: (True, 0.1, 720, 8, 'metric'), Averages -> Grammar: 3.2222222222222223, Common Sense: 2.488888888888889, Coherence: 2.5555555555555554, Cohesiveness: 2.4444444444444446
# Combination: (True, 0.1, 720, 16, 'metric'), Averages -> Grammar: 3.16, Common Sense: 2.4285714285714284, Coherence: 2.54, Cohesiveness: 2.5
# Combination: (True, 0.1, 720, 32, 'metric'), Averages -> Grammar: 3.1914893617021276, Common Sense: 2.369565217391304, Coherence: 2.4680851063829787, Cohesiveness: 2.425531914893617
# Combination: (True, 0.1, 720, 64, 'metric'), Averages -> Grammar: 3.186046511627907, Common Sense: 2.5476190476190474, Coherence: 2.5813953488372094, Cohesiveness: 2.511627906976744
# Combination: (True, 0.1, 720, 128, 'metric'), Averages -> Grammar: 3.375, Common Sense: 2.7916666666666665, Coherence: 2.8125, Cohesiveness: 2.75
# Combination: (True, 0.5, 1, 1, 'metric'), Averages -> Grammar: 3.239130434782609, Common Sense: 2.488888888888889, Coherence: 2.5652173913043477, Cohesiveness: 2.5652173913043477
# Combination: (True, 0.5, 1, 8, 'metric'), Averages -> Grammar: 3.3260869565217392, Common Sense: 2.3777777777777778, Coherence: 2.5652173913043477, Cohesiveness: 2.5
# Combination: (True, 0.5, 1, 16, 'metric'), Averages -> Grammar: 3.36, Common Sense: 2.4468085106382977, Coherence: 2.72, Cohesiveness: 2.7
# Combination: (True, 0.5, 1, 32, 'metric'), Averages -> Grammar: 3.234042553191489, Common Sense: 2.511111111111111, Coherence: 2.574468085106383, Cohesiveness: 2.574468085106383
# Combination: (True, 0.5, 1, 64, 'metric'), Averages -> Grammar: 3.130434782608696, Common Sense: 2.391304347826087, Coherence: 2.4565217391304346, Cohesiveness: 2.4130434782608696
# Combination: (True, 0.5, 40, 1, 'metric'), Averages -> Grammar: 3.127659574468085, Common Sense: 2.5, Coherence: 2.5319148936170213, Cohesiveness: 2.5106382978723403
# Combination: (True, 0.5, 40, 8, 'metric'), Averages -> Grammar: 3.159090909090909, Common Sense: 2.302325581395349, Coherence: 2.6136363636363638, Cohesiveness: 2.522727272727273
# Combination: (True, 0.5, 40, 16, 'metric'), Averages -> Grammar: 3.306122448979592, Common Sense: 2.6530612244897958, Coherence: 2.693877551020408, Cohesiveness: 2.673469387755102
# Combination: (True, 0.5, 40, 32, 'metric'), Averages -> Grammar: 3.488888888888889, Common Sense: 2.8255813953488373, Coherence: 2.8666666666666667, Cohesiveness: 2.7555555555555555
# Combination: (True, 0.5, 40, 64, 'metric'), Averages -> Grammar: 3.375, Common Sense: 2.8297872340425534, Coherence: 2.9166666666666665, Cohesiveness: 2.875
# Combination: (True, 0.5, 40, 128, 'metric'), Averages -> Grammar: 3.466666666666667, Common Sense: 2.8444444444444446, Coherence: 2.911111111111111, Cohesiveness: 2.9555555555555557
# Combination: (True, 0.5, 180, 1, 'metric'), Averages -> Grammar: 3.2222222222222223, Common Sense: 2.5348837209302326, Coherence: 2.6444444444444444, Cohesiveness: 2.6222222222222222
# Combination: (True, 0.5, 180, 8, 'metric'), Averages -> Grammar: 3.276595744680851, Common Sense: 2.4782608695652173, Coherence: 2.6595744680851063, Cohesiveness: 2.617021276595745
# Combination: (True, 0.5, 180, 16, 'metric'), Averages -> Grammar: 3.2666666666666666, Common Sense: 2.4318181818181817, Coherence: 2.6, Cohesiveness: 2.488888888888889
# Combination: (True, 0.5, 180, 32, 'metric'), Averages -> Grammar: 3.391304347826087, Common Sense: 2.7333333333333334, Coherence: 2.9130434782608696, Cohesiveness: 2.869565217391304
# Combination: (True, 0.5, 180, 64, 'metric'), Averages -> Grammar: 3.5416666666666665, Common Sense: 2.875, Coherence: 2.9375, Cohesiveness: 2.9583333333333335
# Combination: (True, 0.5, 180, 128, 'metric'), Averages -> Grammar: 3.5416666666666665, Common Sense: 2.8297872340425534, Coherence: 3.0625, Cohesiveness: 3.0625
# Combination: (True, 0.5, 360, 1, 'metric'), Averages -> Grammar: 3.25, Common Sense: 2.4468085106382977, Coherence: 2.6875, Cohesiveness: 2.625
# Combination: (True, 0.5, 360, 8, 'metric'), Averages -> Grammar: 3.404255319148936, Common Sense: 2.5869565217391304, Coherence: 2.6382978723404253, Cohesiveness: 2.595744680851064
# Combination: (True, 0.5, 360, 16, 'metric'), Averages -> Grammar: 3.4285714285714284, Common Sense: 2.5319148936170213, Coherence: 2.816326530612245, Cohesiveness: 2.7346938775510203
# Combination: (True, 0.5, 360, 32, 'metric'), Averages -> Grammar: 3.375, Common Sense: 2.977777777777778, Coherence: 2.9791666666666665, Cohesiveness: 2.9791666666666665
# Combination: (True, 0.5, 360, 64, 'metric'), Averages -> Grammar: 3.5, Common Sense: 3.0869565217391304, Coherence: 3.152173913043478, Cohesiveness: 3.130434782608696
# Combination: (True, 0.5, 360, 128, 'metric'), Averages -> Grammar: 3.5106382978723403, Common Sense: 3.0652173913043477, Coherence: 3.2127659574468086, Cohesiveness: 3.1914893617021276
# Combination: (True, 0.5, 720, 1, 'metric'), Averages -> Grammar: 3.2222222222222223, Common Sense: 2.4545454545454546, Coherence: 2.511111111111111, Cohesiveness: 2.466666666666667
# Combination: (True, 0.5, 720, 8, 'metric'), Averages -> Grammar: 3.3617021276595747, Common Sense: 2.466666666666667, Coherence: 2.5319148936170213, Cohesiveness: 2.5106382978723403
# Combination: (True, 0.5, 720, 16, 'metric'), Averages -> Grammar: 3.282608695652174, Common Sense: 2.608695652173913, Coherence: 2.5652173913043477, Cohesiveness: 2.5434782608695654
# Combination: (True, 0.5, 720, 32, 'metric'), Averages -> Grammar: 3.4347826086956523, Common Sense: 2.7555555555555555, Coherence: 2.760869565217391, Cohesiveness: 2.8043478260869565
# Combination: (True, 0.5, 720, 64, 'metric'), Averages -> Grammar: 3.347826086956522, Common Sense: 3.0930232558139537, Coherence: 3.0217391304347827, Cohesiveness: 2.9565217391304346
# Combination: (True, 0.5, 720, 128, 'metric'), Averages -> Grammar: 3.4285714285714284, Common Sense: 3.3333333333333335, Coherence: 3.2653061224489797, Cohesiveness: 3.204081632653061
# Combination: (True, 1.0, 1, 1, 'metric'), Averages -> Grammar: 3.122448979591837, Common Sense: 2.4166666666666665, Coherence: 2.4285714285714284, Cohesiveness: 2.4081632653061225
# Combination: (True, 1.0, 1, 8, 'metric'), Averages -> Grammar: 3.347826086956522, Common Sense: 2.534090909090909, Coherence: 2.760869565217391, Cohesiveness: 2.6956521739130435
# Combination: (True, 1.0, 1, 16, 'metric'), Averages -> Grammar: 3.3043478260869565, Common Sense: 2.5869565217391304, Coherence: 2.652173913043478, Cohesiveness: 2.630434782608696
# Combination: (True, 1.0, 1, 32, 'metric'), Averages -> Grammar: 3.1458333333333335, Common Sense: 2.4893617021276597, Coherence: 2.625, Cohesiveness: 2.5416666666666665
# Combination: (True, 1.0, 40, 1, 'metric'), Averages -> Grammar: 3.3404255319148937, Common Sense: 2.4680851063829787, Coherence: 2.702127659574468, Cohesiveness: 2.617021276595745
# Combination: (True, 1.0, 40, 8, 'metric'), Averages -> Grammar: 3.3541666666666665, Common Sense: 2.723404255319149, Coherence: 2.7083333333333335, Cohesiveness: 2.6666666666666665
# Combination: (True, 1.0, 40, 16, 'metric'), Averages -> Grammar: 3.3043478260869565, Common Sense: 2.717391304347826, Coherence: 2.8369565217391304, Cohesiveness: 2.782608695652174
# Combination: (True, 1.0, 40, 32, 'metric'), Averages -> Grammar: 3.511111111111111, Common Sense: 2.8863636363636362, Coherence: 2.933333333333333, Cohesiveness: 2.933333333333333
# Combination: (True, 1.0, 40, 64, 'metric'), Averages -> Grammar: 3.5833333333333335, Common Sense: 2.8958333333333335, Coherence: 3.1458333333333335, Cohesiveness: 3.0208333333333335
# Combination: (True, 1.0, 40, 128, 'metric'), Averages -> Grammar: 3.4791666666666665, Common Sense: 2.978723404255319, Coherence: 2.8125, Cohesiveness: 2.8125
# Combination: (True, 1.0, 180, 1, 'metric'), Averages -> Grammar: 3.347826086956522, Common Sense: 2.369565217391304, Coherence: 2.652173913043478, Cohesiveness: 2.630434782608696
# Combination: (True, 1.0, 180, 8, 'metric'), Averages -> Grammar: 3.4186046511627906, Common Sense: 2.7142857142857144, Coherence: 2.8372093023255816, Cohesiveness: 2.744186046511628
# Combination: (True, 1.0, 180, 16, 'metric'), Averages -> Grammar: 3.340909090909091, Common Sense: 2.5853658536585367, Coherence: 2.7954545454545454, Cohesiveness: 2.7045454545454546
# Combination: (True, 1.0, 180, 32, 'metric'), Averages -> Grammar: 3.577777777777778, Common Sense: 2.9302325581395348, Coherence: 3.066666666666667, Cohesiveness: 3.022222222222222
# Combination: (True, 1.0, 180, 64, 'metric'), Averages -> Grammar: 3.577777777777778, Common Sense: 2.911111111111111, Coherence: 3.1777777777777776, Cohesiveness: 3.111111111111111
# Combination: (True, 1.0, 180, 128, 'metric'), Averages -> Grammar: 3.6363636363636362, Common Sense: 3.046511627906977, Coherence: 3.1136363636363638, Cohesiveness: 3.0454545454545454
# Combination: (True, 1.0, 360, 1, 'metric'), Averages -> Grammar: 3.2916666666666665, Common Sense: 2.5319148936170213, Coherence: 2.6666666666666665, Cohesiveness: 2.6458333333333335
# Combination: (True, 1.0, 360, 8, 'metric'), Averages -> Grammar: 3.3191489361702127, Common Sense: 2.391304347826087, Coherence: 2.6382978723404253, Cohesiveness: 2.574468085106383
# Combination: (True, 1.0, 360, 16, 'metric'), Averages -> Grammar: 3.2954545454545454, Common Sense: 2.7209302325581395, Coherence: 2.75, Cohesiveness: 2.7045454545454546
# Combination: (True, 1.0, 360, 32, 'metric'), Averages -> Grammar: 3.5434782608695654, Common Sense: 3.1956521739130435, Coherence: 3.217391304347826, Cohesiveness: 3.119565217391304
# Combination: (True, 1.0, 360, 64, 'metric'), Averages -> Grammar: 3.36, Common Sense: 3.04, Coherence: 3.1, Cohesiveness: 3.04
# Combination: (True, 1.0, 360, 128, 'metric'), Averages -> Grammar: 3.425531914893617, Common Sense: 3.1956521739130435, Coherence: 3.148936170212766, Cohesiveness: 3.0425531914893615
# Combination: (True, 1.0, 720, 1, 'metric'), Averages -> Grammar: 3.217391304347826, Common Sense: 2.4444444444444446, Coherence: 2.5217391304347827, Cohesiveness: 2.5652173913043477
# Combination: (True, 1.0, 720, 8, 'metric'), Averages -> Grammar: 3.3404255319148937, Common Sense: 2.617021276595745, Coherence: 2.702127659574468, Cohesiveness: 2.617021276595745
# Combination: (True, 1.0, 720, 16, 'metric'), Averages -> Grammar: 3.3404255319148937, Common Sense: 2.739130434782609, Coherence: 2.9148936170212765, Cohesiveness: 2.7872340425531914
# Combination: (True, 1.0, 720, 32, 'metric'), Averages -> Grammar: 3.425531914893617, Common Sense: 3.3333333333333335, Coherence: 3.148936170212766, Cohesiveness: 3.106382978723404
# Combination: (True, 1.0, 720, 64, 'metric'), Averages -> Grammar: 3.375, Common Sense: 3.1875, Coherence: 3.0625, Cohesiveness: 3.0208333333333335
# Combination: (True, 1.0, 720, 128, 'metric'), Averages -> Grammar: 3.5, Common Sense: 3.1956521739130435, Coherence: 3.1956521739130435, Cohesiveness: 3.1956521739130435
# Combination: (True, 2.0, 1, 1, 'metric'), Averages -> Grammar: 3.340909090909091, Common Sense: 2.380952380952381, Coherence: 2.477272727272727, Cohesiveness: 2.5681818181818183
# Combination: (True, 2.0, 1, 8, 'metric'), Averages -> Grammar: 3.234042553191489, Common Sense: 2.4680851063829787, Coherence: 2.702127659574468, Cohesiveness: 2.6382978723404253
# Combination: (True, 2.0, 1, 16, 'metric'), Averages -> Grammar: 3.317073170731707, Common Sense: 2.4878048780487805, Coherence: 2.7804878048780486, Cohesiveness: 2.6097560975609757
# Combination: (True, 2.0, 1, 32, 'metric'), Averages -> Grammar: 3.1702127659574466, Common Sense: 2.4130434782608696, Coherence: 2.4680851063829787, Cohesiveness: 2.4680851063829787
# Combination: (True, 2.0, 40, 1, 'metric'), Averages -> Grammar: 3.25, Common Sense: 2.3617021276595747, Coherence: 2.5208333333333335, Cohesiveness: 2.4583333333333335
# Combination: (True, 2.0, 40, 8, 'metric'), Averages -> Grammar: 3.36, Common Sense: 2.72, Coherence: 2.92, Cohesiveness: 2.84
# Combination: (True, 2.0, 40, 16, 'metric'), Averages -> Grammar: 3.5106382978723403, Common Sense: 2.8297872340425534, Coherence: 3.021276595744681, Cohesiveness: 3.0
# Combination: (True, 2.0, 40, 32, 'metric'), Averages -> Grammar: 3.5106382978723403, Common Sense: 2.8085106382978724, Coherence: 2.9148936170212765, Cohesiveness: 2.8297872340425534
# Combination: (True, 2.0, 40, 64, 'metric'), Averages -> Grammar: 3.3541666666666665, Common Sense: 2.702127659574468, Coherence: 2.8958333333333335, Cohesiveness: 2.7916666666666665
# Combination: (True, 2.0, 40, 128, 'metric'), Averages -> Grammar: 3.4791666666666665, Common Sense: 2.9361702127659575, Coherence: 3.0625, Cohesiveness: 2.9583333333333335
# Combination: (True, 2.0, 180, 1, 'metric'), Averages -> Grammar: 3.14, Common Sense: 2.4, Coherence: 2.58, Cohesiveness: 2.52
# Combination: (True, 2.0, 180, 8, 'metric'), Averages -> Grammar: 3.466666666666667, Common Sense: 2.8, Coherence: 2.7555555555555555, Cohesiveness: 2.8222222222222224
# Combination: (True, 2.0, 180, 16, 'metric'), Averages -> Grammar: 3.533333333333333, Common Sense: 2.977777777777778, Coherence: 2.933333333333333, Cohesiveness: 2.933333333333333
# Combination: (True, 2.0, 180, 32, 'metric'), Averages -> Grammar: 3.4468085106382977, Common Sense: 3.0, Coherence: 3.127659574468085, Cohesiveness: 3.021276595744681
# Combination: (True, 2.0, 180, 64, 'metric'), Averages -> Grammar: 3.422222222222222, Common Sense: 3.0, Coherence: 3.022222222222222, Cohesiveness: 3.022222222222222
# Combination: (True, 2.0, 180, 128, 'metric'), Averages -> Grammar: 3.625, Common Sense: 3.0638297872340425, Coherence: 3.1041666666666665, Cohesiveness: 3.0625
# Combination: (True, 2.0, 360, 1, 'metric'), Averages -> Grammar: 3.3125, Common Sense: 2.488888888888889, Coherence: 2.4791666666666665, Cohesiveness: 2.5
# Combination: (True, 2.0, 360, 8, 'metric'), Averages -> Grammar: 3.404255319148936, Common Sense: 2.717391304347826, Coherence: 2.9361702127659575, Cohesiveness: 2.9148936170212765
# Combination: (True, 2.0, 360, 16, 'metric'), Averages -> Grammar: 3.4081632653061225, Common Sense: 3.0625, Coherence: 3.0408163265306123, Cohesiveness: 2.9591836734693877
# Combination: (True, 2.0, 360, 32, 'metric'), Averages -> Grammar: 3.3958333333333335, Common Sense: 3.108695652173913, Coherence: 3.1041666666666665, Cohesiveness: 3.0416666666666665
# Combination: (True, 2.0, 360, 64, 'metric'), Averages -> Grammar: 3.5106382978723403, Common Sense: 3.127659574468085, Coherence: 3.0638297872340425, Cohesiveness: 3.106382978723404
# Combination: (True, 2.0, 360, 128, 'metric'), Averages -> Grammar: 3.4468085106382977, Common Sense: 3.0869565217391304, Coherence: 3.202127659574468, Cohesiveness: 3.106382978723404
# Combination: (True, 2.0, 720, 1, 'metric'), Averages -> Grammar: 3.272727272727273, Common Sense: 2.558139534883721, Coherence: 2.727272727272727, Cohesiveness: 2.6136363636363638
# Combination: (True, 2.0, 720, 8, 'metric'), Averages -> Grammar: 3.3191489361702127, Common Sense: 2.6595744680851063, Coherence: 2.893617021276596, Cohesiveness: 2.74468085106383
# Combination: (True, 2.0, 720, 16, 'metric'), Averages -> Grammar: 3.5434782608695654, Common Sense: 3.3555555555555556, Coherence: 3.239130434782609, Cohesiveness: 3.152173913043478
# Combination: (True, 2.0, 720, 32, 'metric'), Averages -> Grammar: 3.5625, Common Sense: 3.1914893617021276, Coherence: 3.125, Cohesiveness: 3.0625
# Combination: (True, 2.0, 720, 64, 'metric'), Averages -> Grammar: 3.4468085106382977, Common Sense: 3.25531914893617, Coherence: 3.148936170212766, Cohesiveness: 3.0425531914893615
# Combination: (True, 2.0, 720, 128, 'metric'), Averages -> Grammar: 3.36734693877551, Common Sense: 3.3469387755102042, Coherence: 3.306122448979592, Cohesiveness: 3.2857142857142856
# Combination: (True, 4.0, 1, 1, 'metric'), Averages -> Grammar: 3.1458333333333335, Common Sense: 2.4375, Coherence: 2.5, Cohesiveness: 2.4166666666666665
# Combination: (True, 4.0, 1, 8, 'metric'), Averages -> Grammar: 3.4285714285714284, Common Sense: 2.6530612244897958, Coherence: 2.795918367346939, Cohesiveness: 2.693877551020408
# Combination: (True, 4.0, 1, 16, 'metric'), Averages -> Grammar: 3.1555555555555554, Common Sense: 2.3333333333333335, Coherence: 2.566666666666667, Cohesiveness: 2.511111111111111
# Combination: (True, 4.0, 1, 32, 'metric'), Averages -> Grammar: 3.5434782608695654, Common Sense: 2.630434782608696, Coherence: 2.8260869565217392, Cohesiveness: 2.6956521739130435
# Combination: (True, 4.0, 40, 1, 'metric'), Averages -> Grammar: 3.2653061224489797, Common Sense: 2.63265306122449, Coherence: 2.6122448979591835, Cohesiveness: 2.63265306122449
# Combination: (True, 4.0, 40, 8, 'metric'), Averages -> Grammar: 3.511111111111111, Common Sense: 2.9318181818181817, Coherence: 3.066666666666667, Cohesiveness: 2.977777777777778
# Combination: (True, 4.0, 40, 16, 'metric'), Averages -> Grammar: 3.577777777777778, Common Sense: 3.2790697674418605, Coherence: 3.1555555555555554, Cohesiveness: 3.066666666666667
# Combination: (True, 4.0, 40, 32, 'metric'), Averages -> Grammar: 3.395348837209302, Common Sense: 2.7674418604651163, Coherence: 2.953488372093023, Cohesiveness: 2.9069767441860463
# Combination: (True, 4.0, 40, 64, 'metric'), Averages -> Grammar: 3.5, Common Sense: 2.9555555555555557, Coherence: 3.0217391304347827, Cohesiveness: 3.0217391304347827
# Combination: (True, 4.0, 40, 128, 'metric'), Averages -> Grammar: 3.4444444444444446, Common Sense: 2.8666666666666667, Coherence: 3.0, Cohesiveness: 2.9555555555555557
# Combination: (True, 4.0, 180, 1, 'metric'), Averages -> Grammar: 3.260869565217391, Common Sense: 2.466666666666667, Coherence: 2.760869565217391, Cohesiveness: 2.6739130434782608
# Combination: (True, 4.0, 180, 8, 'metric'), Averages -> Grammar: 3.5434782608695654, Common Sense: 3.022222222222222, Coherence: 3.1739130434782608, Cohesiveness: 3.1956521739130435
# Combination: (True, 4.0, 180, 16, 'metric'), Averages -> Grammar: 3.5714285714285716, Common Sense: 2.9347826086956523, Coherence: 3.0408163265306123, Cohesiveness: 2.979591836734694
# Combination: (True, 4.0, 180, 32, 'metric'), Averages -> Grammar: 3.608695652173913, Common Sense: 3.0681818181818183, Coherence: 3.130434782608696, Cohesiveness: 3.130434782608696
# Combination: (True, 4.0, 180, 64, 'metric'), Averages -> Grammar: 3.4893617021276597, Common Sense: 3.0217391304347827, Coherence: 3.0, Cohesiveness: 2.9148936170212765
# Combination: (True, 4.0, 180, 128, 'metric'), Averages -> Grammar: 3.5106382978723403, Common Sense: 3.1739130434782608, Coherence: 3.127659574468085, Cohesiveness: 3.0425531914893615
# Combination: (True, 4.0, 360, 1, 'metric'), Averages -> Grammar: 3.2954545454545454, Common Sense: 2.6904761904761907, Coherence: 2.727272727272727, Cohesiveness: 2.6818181818181817
# Combination: (True, 4.0, 360, 8, 'metric'), Averages -> Grammar: 3.5510204081632653, Common Sense: 3.0833333333333335, Coherence: 3.2244897959183674, Cohesiveness: 3.2448979591836733
# Combination: (True, 4.0, 360, 16, 'metric'), Averages -> Grammar: 3.608695652173913, Common Sense: 3.3260869565217392, Coherence: 3.282608695652174, Cohesiveness: 3.1739130434782608
# Combination: (True, 4.0, 360, 32, 'metric'), Averages -> Grammar: 3.5652173913043477, Common Sense: 3.111111111111111, Coherence: 3.3260869565217392, Cohesiveness: 3.282608695652174
# Combination: (True, 4.0, 360, 64, 'metric'), Averages -> Grammar: 3.5555555555555554, Common Sense: 3.1818181818181817, Coherence: 3.311111111111111, Cohesiveness: 3.2
# Combination: (True, 4.0, 360, 128, 'metric'), Averages -> Grammar: 3.4565217391304346, Common Sense: 3.159090909090909, Coherence: 3.108695652173913, Cohesiveness: 3.0652173913043477
# Combination: (True, 4.0, 720, 1, 'metric'), Averages -> Grammar: 3.1956521739130435, Common Sense: 2.488888888888889, Coherence: 2.608695652173913, Cohesiveness: 2.5652173913043477
# Combination: (True, 4.0, 720, 8, 'metric'), Averages -> Grammar: 3.272727272727273, Common Sense: 3.292682926829268, Coherence: 3.022727272727273, Cohesiveness: 3.0454545454545454
# Combination: (True, 4.0, 720, 16, 'metric'), Averages -> Grammar: 3.4893617021276597, Common Sense: 3.4680851063829787, Coherence: 3.297872340425532, Cohesiveness: 3.234042553191489
# Combination: (True, 4.0, 720, 32, 'metric'), Averages -> Grammar: 3.558139534883721, Common Sense: 3.3255813953488373, Coherence: 3.2093023255813953, Cohesiveness: 3.2325581395348837
# Combination: (True, 4.0, 720, 64, 'metric'), Averages -> Grammar: 3.4468085106382977, Common Sense: 3.382978723404255, Coherence: 3.234042553191489, Cohesiveness: 3.276595744680851
# Combination: (True, 4.0, 720, 128, 'metric'), Averages -> Grammar: 3.4565217391304346, Common Sense: 3.477272727272727, Coherence: 3.260869565217391, Cohesiveness: 3.217391304347826
# Combination: (True, 8.0, 1, 1, 'metric'), Averages -> Grammar: 3.3617021276595747, Common Sense: 2.6739130434782608, Coherence: 2.6595744680851063, Cohesiveness: 2.595744680851064
# Combination: (True, 8.0, 1, 8, 'metric'), Averages -> Grammar: 3.183673469387755, Common Sense: 2.5319148936170213, Coherence: 2.7551020408163267, Cohesiveness: 2.6530612244897958
# Combination: (True, 8.0, 1, 16, 'metric'), Averages -> Grammar: 3.1956521739130435, Common Sense: 2.5652173913043477, Coherence: 2.608695652173913, Cohesiveness: 2.5217391304347827
# Combination: (True, 8.0, 1, 32, 'metric'), Averages -> Grammar: 3.391304347826087, Common Sense: 2.6136363636363638, Coherence: 2.739130434782609, Cohesiveness: 2.717391304347826
# Combination: (True, 8.0, 40, 1, 'metric'), Averages -> Grammar: 3.1777777777777776, Common Sense: 2.3636363636363638, Coherence: 2.6, Cohesiveness: 2.5555555555555554
# Combination: (True, 8.0, 40, 8, 'metric'), Averages -> Grammar: 3.6818181818181817, Common Sense: 3.0930232558139537, Coherence: 3.227272727272727, Cohesiveness: 3.1363636363636362
# Combination: (True, 8.0, 40, 16, 'metric'), Averages -> Grammar: 3.5217391304347827, Common Sense: 3.0869565217391304, Coherence: 3.0434782608695654, Cohesiveness: 2.9347826086956523
# Combination: (True, 8.0, 40, 32, 'metric'), Averages -> Grammar: 3.311111111111111, Common Sense: 3.0454545454545454, Coherence: 2.977777777777778, Cohesiveness: 2.888888888888889
# Combination: (True, 8.0, 40, 64, 'metric'), Averages -> Grammar: 3.4468085106382977, Common Sense: 2.9565217391304346, Coherence: 2.9361702127659575, Cohesiveness: 2.9361702127659575
# Combination: (True, 8.0, 40, 128, 'metric'), Averages -> Grammar: 3.4893617021276597, Common Sense: 2.9347826086956523, Coherence: 3.0106382978723403, Cohesiveness: 2.9574468085106385
# Combination: (True, 8.0, 180, 1, 'metric'), Averages -> Grammar: 3.422222222222222, Common Sense: 2.5681818181818183, Coherence: 2.8222222222222224, Cohesiveness: 2.7555555555555555
# Combination: (True, 8.0, 180, 8, 'metric'), Averages -> Grammar: 3.574468085106383, Common Sense: 3.276595744680851, Coherence: 3.276595744680851, Cohesiveness: 3.1914893617021276
# Combination: (True, 8.0, 180, 16, 'metric'), Averages -> Grammar: 3.6458333333333335, Common Sense: 3.4130434782608696, Coherence: 3.3541666666666665, Cohesiveness: 3.2916666666666665
# Combination: (True, 8.0, 180, 32, 'metric'), Averages -> Grammar: 3.5319148936170213, Common Sense: 3.2, Coherence: 3.148936170212766, Cohesiveness: 3.127659574468085
# Combination: (True, 8.0, 180, 64, 'metric'), Averages -> Grammar: 3.82, Common Sense: 3.32, Coherence: 3.38, Cohesiveness: 3.4
# Combination: (True, 8.0, 180, 128, 'metric'), Averages -> Grammar: 3.642857142857143, Common Sense: 3.369565217391304, Coherence: 3.4591836734693877, Cohesiveness: 3.4285714285714284
# Combination: (True, 8.0, 360, 1, 'metric'), Averages -> Grammar: 3.260869565217391, Common Sense: 2.533333333333333, Coherence: 2.717391304347826, Cohesiveness: 2.608695652173913
# Combination: (True, 8.0, 360, 8, 'metric'), Averages -> Grammar: 3.5, Common Sense: 3.6382978723404253, Coherence: 3.375, Cohesiveness: 3.2708333333333335
# Combination: (True, 8.0, 360, 16, 'metric'), Averages -> Grammar: 3.673469387755102, Common Sense: 3.4081632653061225, Coherence: 3.306122448979592, Cohesiveness: 3.2448979591836733
# Combination: (True, 8.0, 360, 32, 'metric'), Averages -> Grammar: 3.6956521739130435, Common Sense: 3.3555555555555556, Coherence: 3.3260869565217392, Cohesiveness: 3.260869565217391
# Combination: (True, 8.0, 360, 64, 'metric'), Averages -> Grammar: 3.6382978723404253, Common Sense: 3.8085106382978724, Coherence: 3.5319148936170213, Cohesiveness: 3.425531914893617
# Combination: (True, 8.0, 360, 128, 'metric'), Averages -> Grammar: 3.6530612244897958, Common Sense: 3.836734693877551, Coherence: 3.63265306122449, Cohesiveness: 3.5510204081632653
# Combination: (True, 8.0, 720, 1, 'metric'), Averages -> Grammar: 3.1627906976744184, Common Sense: 2.4651162790697674, Coherence: 2.558139534883721, Cohesiveness: 2.511627906976744
# Combination: (True, 8.0, 720, 8, 'metric'), Averages -> Grammar: 3.6041666666666665, Common Sense: 4.020833333333333, Coherence: 3.5, Cohesiveness: 3.4583333333333335
# Combination: (True, 8.0, 720, 16, 'metric'), Averages -> Grammar: 3.6808510638297873, Common Sense: 4.0, Coherence: 3.617021276595745, Cohesiveness: 3.595744680851064
# Combination: (True, 8.0, 720, 32, 'metric'), Averages -> Grammar: 3.723404255319149, Common Sense: 3.9782608695652173, Coherence: 3.617021276595745, Cohesiveness: 3.617021276595745
# Combination: (True, 8.0, 720, 64, 'metric'), Averages -> Grammar: 3.847826086956522, Common Sense: 4.044444444444444, Coherence: 3.5652173913043477, Cohesiveness: 3.5869565217391304
# Combination: (True, 8.0, 720, 128, 'metric'), Averages -> Grammar: 3.702127659574468, Common Sense: 3.883720930232558, Coherence: 3.5319148936170213, Cohesiveness: 3.4893617021276597
# Combination: (True, 16.0, 1, 1, 'metric'), Averages -> Grammar: 3.533333333333333, Common Sense: 3.0681818181818183, Coherence: 3.2222222222222223, Cohesiveness: 3.1555555555555554
# Combination: (True, 16.0, 1, 8, 'metric'), Averages -> Grammar: 3.5348837209302326, Common Sense: 3.119047619047619, Coherence: 3.116279069767442, Cohesiveness: 3.0232558139534884
# Combination: (True, 16.0, 1, 16, 'metric'), Averages -> Grammar: 3.5531914893617023, Common Sense: 3.282608695652174, Coherence: 3.2127659574468086, Cohesiveness: 3.1914893617021276
# Combination: (True, 16.0, 1, 32, 'metric'), Averages -> Grammar: 3.5833333333333335, Common Sense: 3.2083333333333335, Coherence: 3.25, Cohesiveness: 3.1041666666666665
# Combination: (True, 16.0, 40, 1, 'metric'), Averages -> Grammar: 3.5813953488372094, Common Sense: 3.45, Coherence: 3.3255813953488373, Cohesiveness: 3.2093023255813953
# Combination: (True, 16.0, 40, 8, 'metric'), Averages -> Grammar: 3.84, Common Sense: 4.416666666666667, Coherence: 3.84, Cohesiveness: 3.84
# Combination: (True, 16.0, 40, 16, 'metric'), Averages -> Grammar: 3.9166666666666665, Common Sense: 4.434782608695652, Coherence: 3.875, Cohesiveness: 3.8541666666666665
# Combination: (True, 16.0, 40, 32, 'metric'), Averages -> Grammar: 3.9, Common Sense: 4.408163265306122, Coherence: 3.88, Cohesiveness: 3.88
# Combination: (True, 16.0, 40, 64, 'metric'), Averages -> Grammar: 3.82, Common Sense: 4.416666666666667, Coherence: 3.86, Cohesiveness: 3.8
# Combination: (True, 16.0, 40, 128, 'metric'), Averages -> Grammar: 3.9148936170212765, Common Sense: 4.434782608695652, Coherence: 3.893617021276596, Cohesiveness: 3.872340425531915
# Combination: (True, 16.0, 180, 1, 'metric'), Averages -> Grammar: 3.617021276595745, Common Sense: 3.3260869565217392, Coherence: 3.234042553191489, Cohesiveness: 3.148936170212766
# Combination: (True, 16.0, 180, 8, 'metric'), Averages -> Grammar: 3.893617021276596, Common Sense: 4.733333333333333, Coherence: 4.085106382978723, Cohesiveness: 4.0212765957446805
# Combination: (True, 16.0, 180, 16, 'metric'), Averages -> Grammar: 3.9782608695652173, Common Sense: 4.717391304347826, Coherence: 4.0, Cohesiveness: 3.9347826086956523
# Combination: (True, 16.0, 180, 32, 'metric'), Averages -> Grammar: 4.0212765957446805, Common Sense: 4.808510638297872, Coherence: 4.085106382978723, Cohesiveness: 4.042553191489362
# Combination: (True, 16.0, 180, 64, 'metric'), Averages -> Grammar: 3.857142857142857, Common Sense: 4.583333333333333, Coherence: 3.979591836734694, Cohesiveness: 3.938775510204082
# Combination: (True, 16.0, 180, 128, 'metric'), Averages -> Grammar: 3.893617021276596, Common Sense: 4.555555555555555, Coherence: 3.9148936170212765, Cohesiveness: 3.851063829787234
# Combination: (True, 16.0, 360, 1, 'metric'), Averages -> Grammar: 3.466666666666667, Common Sense: 3.022727272727273, Coherence: 3.066666666666667, Cohesiveness: 3.0
# Combination: (True, 16.0, 360, 8, 'metric'), Averages -> Grammar: 3.9375, Common Sense: 4.276595744680851, Coherence: 3.9375, Cohesiveness: 3.8541666666666665
# Combination: (True, 16.0, 360, 16, 'metric'), Averages -> Grammar: 3.8125, Common Sense: 4.212765957446808, Coherence: 3.75, Cohesiveness: 3.7291666666666665
# Combination: (True, 16.0, 360, 32, 'metric'), Averages -> Grammar: 3.7777777777777777, Common Sense: 4.2444444444444445, Coherence: 3.8666666666666667, Cohesiveness: 3.8444444444444446
# Combination: (True, 16.0, 360, 64, 'metric'), Averages -> Grammar: 3.9555555555555557, Common Sense: 4.681818181818182, Coherence: 4.022222222222222, Cohesiveness: 4.022222222222222
# Combination: (True, 16.0, 360, 128, 'metric'), Averages -> Grammar: 3.8958333333333335, Common Sense: 4.680851063829787, Coherence: 4.020833333333333, Cohesiveness: 4.0
# Combination: (True, 16.0, 720, 1, 'metric'), Averages -> Grammar: 3.4565217391304346, Common Sense: 3.0, Coherence: 3.0652173913043477, Cohesiveness: 2.9782608695652173
# Combination: (True, 16.0, 720, 8, 'metric'), Averages -> Grammar: 4.0, Common Sense: 4.760869565217392, Coherence: 4.127659574468085, Cohesiveness: 4.085106382978723
# Combination: (True, 16.0, 720, 16, 'metric'), Averages -> Grammar: 3.9166666666666665, Common Sense: 4.723404255319149, Coherence: 4.1875, Cohesiveness: 4.1875
# Combination: (True, 16.0, 720, 32, 'metric'), Averages -> Grammar: 4.042553191489362, Common Sense: 4.739130434782608, Coherence: 4.042553191489362, Cohesiveness: 4.0
# Combination: (True, 16.0, 720, 64, 'metric'), Averages -> Grammar: 3.979591836734694, Common Sense: 4.666666666666667, Coherence: 3.979591836734694, Cohesiveness: 4.020408163265306
# Combination: (True, 16.0, 720, 128, 'metric'), Averages -> Grammar: 3.9468085106382977, Common Sense: 4.804347826086956, Coherence: 4.0638297872340425, Cohesiveness: 4.042553191489362

# %%
# Save the results to a CSV file
grouped_averages.to_csv('grouped_averages.csv', index=False)

# %%
# Replace the None values with NaN for proper handling
filtered_df[['Grammar', 'Common Sense', 'Coherence', 'Cohesiveness']] = filtered_df[['Grammar', 'Common Sense', 'Coherence', 'Cohesiveness']].apply(pd.to_numeric, errors='coerce')

# Group by the specified columns and calculate the average for the specified columns
grouped_averages = filtered_df.groupby(['loc_and_org', 'epsilon', 'num_cluster', 'K', 'dp_type']).agg({
    'Grammar': 'mean',
    'Common Sense': 'mean',
    'Coherence': 'mean',
    'Cohesiveness': 'mean'
}).reset_index()

# Pivot the data to get the desired format
pivot_df = grouped_averages.pivot_table(
    index=['loc_and_org', 'K'],
    columns=['epsilon', 'num_cluster'],
    values=['Grammar', 'Common Sense', 'Coherence', 'Cohesiveness']
)

# Flatten the multi-level columns
pivot_df.columns = ['_'.join(map(str, col)).strip() for col in pivot_df.columns.values]

# Reset the index to flatten the dataframe
pivot_df = pivot_df.reset_index()

# Save the resulting dataframe to a CSV file
pivot_df.to_csv('formatted_grouped_averages.csv', index=False)

print("Results have been saved to 'formatted_grouped_averages.csv'.")
# Out:
# Results have been saved to 'formatted_grouped_averages.csv'.
